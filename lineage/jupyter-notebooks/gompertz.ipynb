# %%
import scipy.stats as sp
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5)
c_list = np.linspace(0.1, 3, num=8)
for c in c_list:
    plt.plot(x, sp.gompertz.pdf(x, c), alpha=0.6, label=str(c))
    
plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1.05))

# %%
x = np.linspace(0, 5)
scale_list = np.linspace(0.5, 3, num=8)
for i in scale_list:
    plt.plot(x, sp.gompertz.pdf(x, c=0.75, scale=i), alpha=0.6, label=str(i))
    
plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1.05))

# %%
cGom = 0.75
tau = np.zeros((500, 8))

for i in range(8):
    for n in range(500):
        tau[n, i] = sp.gompertz.rvs(cGom, scale=scale_list[i])
    plt.hist(tau[:, i], label=str(scale_list[i]))
    plt.xlim(0,6)
    plt.ylim(0,100)
    plt.title("scale")
    plt.xlabel("tau")
    plt.ylabel("#")
    plt.legend()
    plt.show()
    print("mean for scale=" + str(scale_list[i]) + " is " + str(np.mean(tau[:,i])))
# Out:
# mean for scale=0.5 is 0.37009841234261454
# mean for scale=0.8571428571428572 is 0.6309783231555941
# mean for scale=1.2142857142857144 is 0.882939699628688
# mean for scale=1.5714285714285714 is 1.136406159467305
# mean for scale=1.9285714285714286 is 1.3369540374580948
# mean for scale=2.2857142857142856 is 1.7349341477055855
# mean for scale=2.642857142857143 is 1.8868258076240476
# mean for scale=3.0 is 2.197676367316868

# %%
scaleGom = 1.25
tau = np.zeros((500, 8))

for i in range(8):
    for n in range(500):
        tau[n, i] = sp.gompertz.rvs(c=c_list[i], scale=scaleGom)
    plt.hist(tau[:, i], label=str(c_list[i]))
    plt.xlim(0,5)
    plt.ylim(0,170)
    plt.title("C")
    plt.xlabel("tau")
    plt.ylabel("#")
    plt.legend()
    plt.show()
    print("mean for c=" + str(c_list[i]) + " is " + str(np.mean(tau[:,i])))
# Out:
# mean for c=0.1 is 2.5750673802255477
# mean for c=0.5142857142857142 is 1.1305411929321927
# mean for c=0.9285714285714285 is 0.786962165007305
# mean for c=1.342857142857143 is 0.5971116990040741
# mean for c=1.7571428571428571 is 0.5008839149835403
# mean for c=2.1714285714285713 is 0.403029760208785
# mean for c=2.585714285714286 is 0.3801491521808125
# mean for c=3.0 is 0.3371405206763969
