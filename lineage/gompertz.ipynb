# %%
import scipy.stats as sp
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5)
c_list = np.linspace(0.1, 3, num=8)
for c in c_list:
    plt.plot(x, sp.gompertz.pdf(x, c), alpha=0.6, label=str(c))
    
plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1.05))

# %%
x = np.linspace(0, 5)
scale_list = np.linspace(0.5, 3, num=8)
for i in scale_list:
    plt.plot(x, sp.gompertz.pdf(x, c=0.75, scale=i), alpha=0.6, label=str(i))
    
plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1.05))

# %%
cGom = 0.75
tau = np.zeros((500, 8))

for i in range(8):
    for n in range(500):
        tau[n, i] = sp.gompertz.rvs(cGom, scale=scale_list[i])

# %%
for n in range(8):
    plt.hist(tau[:, n], label=str(scale_list[n]))
    plt.xlim(0,6)
    plt.ylim(0,100)
    plt.title("scale")
    plt.xlabel("tau")
    plt.ylabel("#")
    plt.legend()
    plt.show()
    print("mean for " + str(scale_list[n]) + " is " + str(np.mean(tau[:,n])))
# Out:
# mean for 0.5 is 2.4664133672864708
# mean for 0.8571428571428572 is 1.1749522719446215
# mean for 1.2142857142857144 is 0.7703250284007839
# mean for 1.5714285714285714 is 0.5926617544103482
# mean for 1.9285714285714286 is 0.4688788902583167
# mean for 2.2857142857142856 is 0.41690369763763035
# mean for 2.642857142857143 is 0.35294879132751816
# mean for 3.0 is 0.3303189895165174

# %%
scaleGom = 1.25
tau = np.zeros((500, 8))

for i in range(8):
    for n in range(500):
        tau[n, i] = sp.gompertz.rvs(c=c_list[i], scale=scaleGom)
        
for n in range(8):
    plt.hist(tau[:, n], label=str(c_list[n]))
    plt.xlim(0,5)
    plt.ylim(0,170)
    plt.title("C")
    plt.xlabel("tau")
    plt.ylabel("#")
    plt.legend()
    plt.show()
